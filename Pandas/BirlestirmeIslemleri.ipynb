# %% [markdown]
# # Birleştirme (Join) İşlemleri

# %%
import numpy as np
import pandas as pd
m = np.random.randint(1,30, size = (5,3))
df1 = pd.DataFrame(m, columns = ["var1","var2","var3"])
df1
# Out:
#    var1  var2  var3
# 0    26    21    27
# 1    18    29    28
# 2    21    28    14
# 3    28     4     4
# 4    13     1     5

# %%
df2 = df1 + 99

# %%
df2
# Out:
#    var1  var2  var3
# 0   125   120   126
# 1   117   128   127
# 2   120   127   113
# 3   127   103   103
# 4   112   100   104

# %%
pd.concat([df1,df2])
# Out:
#    var1  var2  var3
# 0    26    21    27
# 1    18    29    28
# 2    21    28    14
# 3    28     4     4
# 4    13     1     5
# 0   125   120   126
# 1   117   128   127
# 2   120   127   113
# 3   127   103   103
# 4   112   100   104

# %%
pd.concat([df1,df2], ignore_index = True)
# Out:
#    var1  var2  var3
# 0    26    21    27
# 1    18    29    28
# 2    21    28    14
# 3    28     4     4
# 4    13     1     5
# 5   125   120   126
# 6   117   128   127
# 7   120   127   113
# 8   127   103   103
# 9   112   100   104

# %%
df1.columns
# Out:
# Index(['var1', 'var2', 'var3'], dtype='object')

# %%
df2.columns
# Out:
# Index(['var1', 'var2', 'var3'], dtype='object')

# %%
df2.columns = ["var1","var2","deg3"]

# %%
df2
# Out:
#    var1  var2  deg3
# 0   125   120   126
# 1   117   128   127
# 2   120   127   113
# 3   127   103   103
# 4   112   100   104

# %%
df1
# Out:
#    var1  var2  var3
# 0    26    21    27
# 1    18    29    28
# 2    21    28    14
# 3    28     4     4
# 4    13     1     5

# %%
# pd.concat([df1,df2]) hata verir cunku birinde var3 birinde deg3 yaptik

# %%
pd.concat([df1,df2], join = "inner")
# Out:
#    var1  var2
# 0    26    21
# 1    18    29
# 2    21    28
# 3    28     4
# 4    13     1
# 0   125   120
# 1   117   128
# 2   120   127
# 3   127   103
# 4   112   100

# %%
pd.concat([df1,df2], join = "inner", ignore_index = True)
# Out:
#    var1  var2
# 0    26    21
# 1    18    29
# 2    21    28
# 3    28     4
# 4    13     1
# 5   125   120
# 6   117   128
# 7   120   127
# 8   127   103
# 9   112   100
